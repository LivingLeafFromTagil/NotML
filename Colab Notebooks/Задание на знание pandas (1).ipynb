# %% [markdown]
# ### <center> Titanic

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/My Drive/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# 1. Сколько всего ячеек в полученном датафрейме?

# %%
df.size
# Out:
# 10692

# %% [markdown]
# 2. Сколько строк в датафрейме?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# 3. Сколько в датафрейме столбцов типа данных float64?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4. Найдите возраст самого младшего и самого старшего пассажира

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# 5. Найдите пассажире с id равным 200. Сколько ему лет?

# %%
df[df['PassengerId']==200]
# Out:
#      PassengerId  Survived  Pclass  ...  Fare Cabin  Embarked
# 199          200         0       2  ...  13.0   NaN         S
#
# [1 rows x 12 columns]

# %% [markdown]
# 6. Титаник затонул в 1912 году. Рассчитайте, сколько лет должно быть сегодня всем выжившим пассажирам. Выберите, сколько лет должно быть пассажиру с пассажирским id, равным 311?

# %%
df2 = df[['PassengerId', 'Survived', 'Age']].copy()
df2 = df2[df2['Survived'] == 1]
df2['ActualAge'] = df2['Age'].apply(lambda x: x+109)
df2[df2['PassengerId']==311]
# Out:
#      PassengerId  Survived   Age  ActualAge
# 310          311         1  24.0      133.0

# %% [markdown]
# 7. В начале 20 века один фунт стерлингов стоил 9,46 рублей. Пересчитайте для всех пассажиров, сколько бы стоил билет на Титаник в рублях. Сколько в рублях стоил билет пассажира с PassengerId 248

# %%
df3 = df[['PassengerId', 'Fare']].copy()
df3['RubFare'] = df3['Fare'].apply(lambda x: x * 9.46)
df3[df3['PassengerId']==248]
# Out:
#      PassengerId  Fare  RubFare
# 247          248  14.5   137.17

# %% [markdown]
# 8. Какое количество пассажиров было старше 25, но младше 35 лет (не включайте пассажиров в возрасте 25 и 35)?

# %%
df[(df['Age']>25) & (df['Age']<35)].count()
# Out:
# PassengerId    178
# Survived       178
# Pclass         178
# Name           178
# Sex            178
# Age            178
# SibSp          178
# Parch          178
# Ticket         178
# Fare           178
# Cabin           32
# Embarked       178
# dtype: int64

# %% [markdown]
# 9. Какое количество женщин было в возрасте от 45 лет и выше (включая женщин 45 лет)?

# %%
df[(df['Sex']=='female')&(df['Age']>=45)].count()
# Out:
# PassengerId    36
# Survived       36
# Pclass         36
# Name           36
# Sex            36
# Age            36
# SibSp          36
# Parch          36
# Ticket         36
# Fare           36
# Cabin          20
# Embarked       35
# dtype: int64

# %% [markdown]
# 10. Сколько человек купили билеты первого и второго классов?

# %%
df[(df['Pclass'] == 1)|(df['Pclass'] == 2)].count()
# Out:
# PassengerId    400
# Survived       400
# Pclass         400
# Name           400
# Sex            400
# Age            359
# SibSp          400
# Parch          400
# Ticket         400
# Fare           400
# Cabin          192
# Embarked       398
# dtype: int64

# %% [markdown]
# 11. Используя группировку найти средний возраст мужчин и женщин

# %%
df.groupby('Sex')[['Age']].mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %% [markdown]
# 12. Используя группировку найти максимальный возраст поссажира в каждом классе

# %%
df.groupby('Pclass')[['Age']].max()
# Out:
#          Age
# Pclass
# 1       80.0
# 2       70.0
# 3       74.0

# %% [markdown]
# 13. Выбрать следующий срез данных: с 100 по 139 индекс, со столбца PassengerId по Fare. По выбранному срезу найти среднюю стоимость билета

# %%
cutDF = df.loc[100:140, 'PassengerId':'Fare']
cutDF[['Fare']].mean()
# Out:
# Fare    26.90721
# dtype: float64

# %% [markdown]
# 14. По выбранному выше срезу данный найти, сколько человек купили билеты первого класса

# %%
cutDF[cutDF['Pclass'] == 1].count()
# Out:
# PassengerId    7
# Survived       7
# Pclass         7
# Name           7
# Sex            7
# Age            7
# SibSp          7
# Parch          7
# Ticket         7
# Fare           7
# dtype: int64

# %% [markdown]
# 15. В каких из перечисленных столбцов есть пропущенные значения (NaN)?

# %%
# cutDF.isna().any()
df.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# 16. Найти количество пропущенных значений в столбцe Age

# %%
# cutDF[cutDF['Age'].isna()==True].shape
df[df['Age'].isna()==True].shape
# Out:
# (177, 12)

# %% [markdown]
# 17. Заполните пропущенные значения в столбце Age нулем и пересчитайте средний возраст пассажиров, чему он теперь равен (значение округлить до целого)?

# %%
# cutDF[['Age']].fillna(0).mean().astype('int64')
int(df[['Age']].fillna(0).mean()+0.5)
# Out:
# 24

# %% [markdown]
# 18. Считайте данные из файла embarking_town.xlsx. Данные предсавляют собой справочник городов отправления и содержат два столбца: шифр города (Embarking_id) и название города (Embarking_town). В датасете titanic указан только шифр города. Добавьте название города в датасет. Используйте функцию merge для объединения данных. Сколько строк у полученного датафрема?

# %%
edf = pd.read_excel('drive/My Drive/embarking_town.xlsx')
edf.head()
edf2 = edf.rename(columns={'Embarking_id':'Embarked'})
edf2
# Out:
#   Embarked Embarking_town
# 0        S    Southampton
# 1        C      Cherbourg
# 2        Q     Queenstown
# 3        L      Lusitania

# %%
newDF = df.merge(edf2, on='Embarked', how='left')
newDF
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Embarking_town
# 0              1         0       3  ...   NaN        S     Southampton
# 1              2         1       1  ...   C85        C       Cherbourg
# 2              3         1       3  ...   NaN        S     Southampton
# 3              4         1       1  ...  C123        S     Southampton
# 4              5         0       3  ...   NaN        S     Southampton
# ..           ...       ...     ...  ...   ...      ...             ...
# 886          887         0       2  ...   NaN        S     Southampton
# 887          888         1       1  ...   B42        S     Southampton
# 888          889         0       3  ...   NaN        S     Southampton
# 889          890         1       1  ...  C148        C       Cherbourg
# 890          891         0       3  ...   NaN        Q      Queenstown
#
# [891 rows x 13 columns]

# %% [markdown]
# 19. Найдите, из какого города не было пассажиров на Титанике?

# %%
df.merge(edf2, on='Embarked', how='outer')
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Embarking_town
# 0            1.0       0.0     3.0  ...   NaN        S     Southampton
# 1            3.0       1.0     3.0  ...   NaN        S     Southampton
# 2            4.0       1.0     1.0  ...  C123        S     Southampton
# 3            5.0       0.0     3.0  ...   NaN        S     Southampton
# 4            7.0       0.0     1.0  ...   E46        S     Southampton
# ..           ...       ...     ...  ...   ...      ...             ...
# 887        886.0       0.0     3.0  ...   NaN        Q      Queenstown
# 888        891.0       0.0     3.0  ...   NaN        Q      Queenstown
# 889         62.0       1.0     1.0  ...   B28      NaN             NaN
# 890        830.0       1.0     1.0  ...   B28      NaN             NaN
# 891          NaN       NaN     NaN  ...   NaN        L       Lusitania
#
# [892 rows x 13 columns]
