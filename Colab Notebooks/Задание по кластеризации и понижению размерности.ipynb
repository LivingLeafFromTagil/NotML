# %% [markdown]
# ### <center> Задание по кластеризации

# %% [markdown]
# **Цель задания:** провести кластеризацию покупателей торгового центра.
# Необходимо выполнить следующие шаги:
#
# 1. Провести небольшой анализ и визуализацию данных
# 2. Провести кластеризацию методов KMeans
# 2. Найти оптимальное количество кластеров для KMeans, используя:
#     - метод локтя
#     - показатель силуэта + силуэтные диаграммы
# 4. Провести интерпретацию кластеров KMeans
# 5. Провести кластеризаицию методом DBScan, сравнить с результатами кластеризации KMeans, похожие ли кластеры получились

# %% [markdown]
# ### <center> Задание по понижению размерности
# **Цель задания:** использовать методы понижения размерности, чтобы сжатые визуализировать данные в двумерном пространстве
#
# 1. Применить методы понижения размерности PCA, tSNE и LLE, чтобы понизить размерность данных до 2-х измерений
# 2. Визуализировать результаты с помощью диаграммы рассеяния
# 3. Прокомменировать полученные результаты: выделяются ли группы объектов или какие-либо другие зависимости
#
# 4*. Попробуйте проинтерпретировать коэффициенты компонент PCA, если это возможно

# %%
import pandas as pd
import numpy as np
import sklearn
import os

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('drive/My Drive/Mall_Customers.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # Кластеризация

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
plt.figure(figsize=(10, 6))

x = df['Gender']
y = df['Age']

plt.plot(x, y)


plt.show()
